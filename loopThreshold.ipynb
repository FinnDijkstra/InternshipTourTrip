# %%
# %run PreprocessingTours.ipynb
upperbounds=[3,5,7,10,15,20,30,50,100,1000,10000,100000]
# upperbounds=[5]
thresholds=[0,0.0001,0.001,0.01,0.1]
for upperbound in upperbounds:
    for threshold in thresholds:
        print(f'run optimisation with upperbound {upperbound}, threshold {threshold}')
        # %run OptimisationThreshold.ipynb
# Out:
# ...
# Turning vervoerswijze into string:   0%|          | 0/200507 [00:00<?, ?it/s]C:\Users\soudeveldhuis\AppData\Local\Temp\ipykernel_7436\3789425402.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Vervoerswijze'][a]=newstring
# ...
# Creating the probability matrix:   0%|          | 0/200507 [00:00<?, ?it/s]c:\Users\soudeveldhuis\Anaconda3\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# Creating the probability matrix: 100%|██████████| 200507/200507 [08:00<00:00, 417.03it/s]
# Stored 'agents' (list)
# Stored 'usedagents' (dict)
# Stored 'zones' (list)
# Stored 'prob' (list)
# Stored 'obsMatrix' (DataFrame)
# Stored 'maxagentnr' (int)
# ...
